# %%
tm = {
'1':'มกราคม',
'2': 'กุมภาพันธ์',
'3': 'มีนาคม',
'4': 'เมษายน',
'5': 'พฤษภาคม',
'6': 'นมิถุนายน',
'7': 'กรกฎาคม',
'8': 'สิงหาคม',
'9': 'กันยายน',} #'October': 'ตุลาคม', 'November': 'พฤศจิกายน', 'December': 'ธันวาคม'}

# %%
from os import listdir
from os.path import isfile, join
import pandas as pd, numpy as np
from scipy import stats
onlyfiles = [f for f in listdir('WP') if isfile(join('WP', f))]
tms = pd.Series(onlyfiles)
tms
# Out:
# 0          Final 1 โครงสร้างไม้เดือนกันยายน 63 r4.xlsx
# 1              Finalโครงสร้างไม้เดือนเมษายน 63 V4.xlsx
# 2                  โครงสร้างไม้เดือนกรกฎาคม 63 V6.xlsx
# 3               โครงสร้างไม้เดือนกุมภาพันธ์ 63v 5.xlsx
# 4                  โครงสร้างไม้เดือนพฤษภาคม 63 V2.xlsx
# 5                    โครงสร้างไม้เดือนมกราคม63 V4.xlsx
# 6    โครงสร้างไม้เดือนมิถุนายน 63 v4 1(ปรับunit use...
# 7    โครงสร้างไม้เดือนมีนาคม 63 v4ปรับระหว่างเดือน....
# 8                     โครงสร้างไม้เดือนสิงหาคม 63.xlsx
# dtype: object

# %%
def CPF(x):
    cpi = [i for i in x if i>0]
    if len(cpi) > 1:
        zs  = stats.zscore(cpi); fzs=[]
        for i in range(len(cpi)):
            if np.abs(zs[i]) < 1.4:
                fzs.append(cpi[i])
        return fzs
    else:
        return cpi

# %%
SADA = {} #SADA, SAD, CPM, CPSD = {}, {}, {}, {}
for tm_ in tm.keys(): # ['January']: #
    fn = tms[tms.str.contains(tm[tm_])].values[0]
    ex = pd.read_excel('WP/'+fn, sheet_name='โครงสร้างไม้', index_col=0, header=2)
    
    # Get only rows with Sloc
    N = np.array(ex['Storage Location'].str.contains('N').fillna(False))
    W = np.array(ex['Storage Location'].str.contains('W').fillna(False))
    NW= N+W
    
    # Clean Competitor Price
    cp = ex['ราคาคู่แข่ง'].apply(lambda x: str(x)[:5]).str.replace('-','').str.replace(',','')
    cpi = cp.astype(float)
    #cpi = cpi.fillna(0)
    ex['CP'] = cpi
    
    # Group Agents and CP mby Sloc
    Sloc = ex[NW].groupby('Storage Location')['รายชื่อ'].unique().index
    Agent= ex[NW].groupby('Storage Location')['รายชื่อ'].unique().values
    nCP  = ex[NW].groupby('Storage Location')['คู่แข่ง'].unique().values
    CP   = ex[NW].groupby('Storage Location')['CP'].unique().apply(CPF)
    QC   = ex[NW].groupby('Storage Location')['ปริมาณส่งคู่แข่ง'].sum()
    QT   = ex[NW].groupby('Storage Location')['ปริมาณไม้ทั้งหมด '].sum()
    QS   = ex[NW].groupby('Storage Location')['SFT ปริมาณจัดหา'].sum()
    
    SA = pd.DataFrame({'Agent': Agent, 'CP': CP, 'nCP':nCP, 'QC':QC, 'QT':QT, 'QS':QS}, index=Sloc)
    SA['nAgent'] = SA['Agent'].apply(len)
    SA['nCP']    = SA['nCP'].apply(len)
    SA['CPM']    = SA['CP'].apply(np.mean)
    SA['CPSD']   = SA['CP'].apply(np.std)
    SA['Year']   = '2020'
    SA['Month']  = tm_
    
    # Save and Print Information
    #SAD[tm_] = SA['nAgent']#.sort_values(by='nAgent', ascending=False)
    #CPM[tm_] = SA['CPM']#.sort_values(by='nAgent', ascending=False)
    #CPSD[tm_]= SA['CPSD']#.sort_values(by='nAgent', ascending=False)
    SADA[tm_] = SA
    print(tm_, SA['nAgent'].sum(), SA['nAgent'].mean(), SA['nCP'].mean(), SA['CPM'].mean(), SA['CPSD'].mean())
# Out:
# 1 212 5.170731707317073 1.3902439024390243 1199.9593495934957 50.885890582815016
# 2 206 5.024390243902439 1.2439024390243902 1188.1707317073171 34.51219512195122
# 3 239 5.558139534883721 1.2790697674418605 1190.2325581395348 35.348837209302324
# 4 258 6.142857142857143 1.2857142857142858 1166.4285714285713 36.19047619047619
# 5 309 7.536585365853658 1.3170731707317074 1145.6097560975609 29.969270213173616
# 6 307 7.487804878048781 1.2682926829268293 1135.2439024390244 20.853658536585368
# 7 301 7.341463414634147 1.2682926829268293 1155.9756097560976 31.829268292682926
# 8 247 6.024390243902439 1.2439024390243902 1170.4065040650407 40.05758430356664
# 9 227 5.536585365853658 1.2439024390243902 1171.7601626016262 38.24051113283494

# %%
SADA['1']
# Out:
#                                                               Agent  \
# Storage Location
# N1BK              [หน้าลานอ.บางระกำ , หน้าลานอ.บางระกำ ทีมตัดหน้...
# N1BT                                 [Agent หน้าไร่ สงัด สอนปากพิง]
# N1DG              [หน้าลานอ.ศรีสำโรง , หน้าลานอ.ศรีสำโรง ทีมตัดห...
# N1DK              [หน้าลาน ต.ดงประคำ , หน้าลาน ต.ดงประคำ ทีมตัดห...
# N1NK              [หน้าลานต.เนินกุ่ม , หน้าลานต.เนินกุ่ม ทีมตัดห...
# N1PB              [หน้าลานกำนันสบาย สุขเกษม , หน้าลานกำนันสบาย ส...
# N1PR              [หน้าลาน อ.พรหมพิราม , หน้าลาน อ.พรหมพิราม  ที...
# N1SG              [หน้าลานสหกรณ์ อ.ไทรงาม, หน้าลานสหกรณ์ อ.ไทรงา...
# N1ST              [หน้าลานสหกรณ์ตรอน (ติด 4 เลน) , หน้าลานสหกรณ์...
# N1TC              [หน้าลาน ต.ท่าช้าง อ.พรหมพิราม จ.พิษณุโลก, หน้...
# N1TH                [หน้าลานบ้านด่านลานหอย, เอเย่นต์ นายเทพ ชูแผ้ว]
# N1TK              [หน้าลาน ศูนย์ฯตาก, หน้าลาน ศูนย์ฯตาก ทีมตัดหน...
# N1TL              [เอเย่นต์นายประสิทธิ์ รอดทนง, เอเย่นต์ สมรักษ์...
# N1TN              [หน้าลานท่าฉนวน, หน้าลานท่าฉนวน ทีมตัดหน้าลาน,...
# N1WT              [เอเย่นต์ห้างหุ้นส่วน สราวุฒิ ค้าไม้, Agent หน...
# N1YS              [หน้าลานยางซ้าย, หน้าลานยางซ้าย ทีมตัดหน้าลาน,...
# N2BS              [หน้าลานบึงปลาทู, หน้าลานบึงปลาทู (ทีมตัดประจำ...
# N2BY              [หน้าลานบัญญัติ, หน้าลานบัญญัติ (ทีมตัดประจำ),...
# N2KP              [หน้าลานโกรกพระ, หน้าลานโกรกพระ (ทีมตัดประจำ),...
# N2MK              [หน้าลานปางมะค่า, หน้าลานปางมะค่า (ทีมตัดประจำ...
# N2NS              [หน้าลานหนองหญ้าไซ, หน้าลานหนองหญ้าไซ (ทีมตัดป...
# N2PG              [หน้าลานปางงู, หน้าลานปางงู  (ทีมตัดประจำ), หน...
# N2PK              [หน้าลานลูกน้ำ, หน้าลานลูกน้ำ (ทีมตัดประจำ), ห...
# N2SB              [หน้าลานสลกบาตร, หน้าลานสลกบาตร (ทีมตัดประจำ),...
# N2ST              [หน้าลานร้อยไร่, หน้าลานร้อยไร่ (ทีมตัดประจำ),...
# N2WK              [หน้าลานวังตะเคียน, หน้าลานวังตะเคียน (ทีมตัดป...
# N2WP              [หน้าลานวังชะพลู, หน้าลานวังชะพลู (ทีมตัดประจำ...
# N3CD              [หน้าลานชนแดน, หน้าลานชนแดน(ทีมตัดนายสุพรรณ นั...
# N3CS                                               [หน้าลานชุมแสง ]
# N3DT                                             [หน้าลานด่านขุนทด]
# N3NB                                            [หน้าลาน อ.หนองบัว]
# N3ND                                            [หน้าลานหนองบัวแดง]
# N3PC                                 [หน้าลานสหกรณ์โพธิ์ประทับช้าง]
# N3TK              [หน้าลานอ.ท่าตะโก, หน้าลานอ.ท่าตะโก (ทีมตัดนาย...
# N3TL                                           [หน้าลานสหกรณ์ตาคลี]
# N3TN              [หน้าลานทะนง, หน้าลานทะนง (ทีมตัดนายเสมียน  รอ...
# N3WR                                           [หน้าลานวิเชียรบุรี]
# W1CP              [เกรียงชัย แซ่ลี้, คณาวุฒิ เชื้อดี, พิมพ์ภัช ช...
# W1DT              [บุญส่ง หาดทราย, พรรณทิพย์ วกุลชัย VIP, รัตติก...
# W1IN              [เตี๊ยก  ลิ้มประเสริฐ , ขวัญรัตน์ น้ำทับทิม, ป...
# W1SR              [อนันต์ สารีวงษ์ (ทีมตัดประจำ), ฉลอง เม่าตัน (...
#
#                                         CP  nCP      QC      QT      QS  \
# Storage Location
# N1BK                              [1200.0]    1     0.0     0.0   580.0
# N1BT                              [1200.0]    1     0.0    50.0    50.0
# N1DG                              [1200.0]    1     0.0     0.0   610.0
# N1DK                              [1200.0]    1     0.0     0.0   520.0
# N1NK                              [1200.0]    1     0.0   250.0   760.0
# N1PB                              [1200.0]    1     0.0     0.0   830.0
# N1PR                              [1200.0]    1   170.0  1100.0  1470.0
# N1SG                      [1200.0, 1500.0]    2   250.0   760.0  1030.0
# N1ST                              [1200.0]    1     0.0     0.0   500.0
# N1TC                              [1200.0]    1     0.0     0.0   530.0
# N1TH                              [1200.0]    1     0.0     0.0   210.0
# N1TK                              [1200.0]    1     0.0     0.0   910.0
# N1TL                              [1200.0]    1     0.0     0.0   200.0
# N1TN                              [1200.0]    1     0.0     0.0   960.0
# N1WT                              [1200.0]    1  2100.0  5050.0  2950.0
# N1YS                              [1200.0]    1     0.0     0.0   960.0
# N2BS                      [1070.0, 1350.0]    2  1200.0  2530.0  1470.0
# N2BY                      [1040.0, 1350.0]    2   500.0  1860.0  1360.0
# N2KP                      [1000.0, 1350.0]    2   500.0  2480.0  2310.0
# N2MK                      [1070.0, 1350.0]    2  1200.0  2280.0  2900.0
# N2NS                      [1200.0, 1350.0]    2     0.0  2060.0  2660.0
# N2PG                      [1000.0, 1350.0]    2   500.0   750.0   560.0
# N2PK                      [1000.0, 1350.0]    2   500.0  2580.0  2180.0
# N2SB                      [1050.0, 1030.0]    2  1200.0  2700.0  1190.0
# N2ST                       [950.0, 1350.0]    3   500.0  3200.0  2030.0
# N2WK                      [1000.0, 1350.0]    2   500.0  1030.0   850.0
# N2WP                       [950.0, 1350.0]    2   500.0  1490.0   790.0
# N3CD                      [1150.0, 1280.0]    2  1000.0  3700.0  2700.0
# N3CS                              [1070.0]    1   300.0  1500.0  1200.0
# N3DT                              [1090.0]    1  1000.0  2000.0  1000.0
# N3NB                              [1070.0]    1  1000.0  4000.0  3000.0
# N3ND                              [1090.0]    1  1000.0  1500.0   500.0
# N3PC                              [1150.0]    1   400.0  1000.0   600.0
# N3TK                              [1070.0]    1   600.0  3100.0  2500.0
# N3TL                              [1350.0]    1   600.0  1200.0   600.0
# N3TN                              [1150.0]    1   300.0  1100.0   800.0
# N3WR                              [1070.0]    1   500.0  1000.0   500.0
# W1CP              [1350.0, 1600.0, 1200.0]    1   100.0  2700.0  1700.0
# W1DT                      [1380.0, 1400.0]    1   600.0  5100.0  4500.0
# W1IN              [1380.0, 1400.0, 1360.0]    2   700.0  5200.0  4500.0
# W1SR                      [1380.0, 1500.0]    2   650.0  2900.0  2300.0
#
#                   nAgent          CPM        CPSD  Year Month
# Storage Location
# N1BK                   3  1200.000000    0.000000  2020     1
# N1BT                   1  1200.000000    0.000000  2020     1
# N1DG                   2  1200.000000    0.000000  2020     1
# N1DK                   2  1200.000000    0.000000  2020     1
# N1NK                   5  1200.000000    0.000000  2020     1
# N1PB                   3  1200.000000    0.000000  2020     1
# N1PR                   3  1200.000000    0.000000  2020     1
# N1SG                  12  1350.000000  150.000000  2020     1
# N1ST                   2  1200.000000    0.000000  2020     1
# N1TC                   2  1200.000000    0.000000  2020     1
# N1TH                   2  1200.000000    0.000000  2020     1
# N1TK                  10  1200.000000    0.000000  2020     1
# N1TL                   3  1200.000000    0.000000  2020     1
# N1TN                   5  1200.000000    0.000000  2020     1
# N1WT                   8  1200.000000    0.000000  2020     1
# N1YS                   6  1200.000000    0.000000  2020     1
# N2BS                   7  1210.000000  140.000000  2020     1
# N2BY                   6  1195.000000  155.000000  2020     1
# N2KP                   8  1175.000000  175.000000  2020     1
# N2MK                   9  1210.000000  140.000000  2020     1
# N2NS                   9  1275.000000   75.000000  2020     1
# N2PG                   4  1175.000000  175.000000  2020     1
# N2PK                   8  1175.000000  175.000000  2020     1
# N2SB                   4  1040.000000   10.000000  2020     1
# N2ST                  11  1150.000000  200.000000  2020     1
# N2WK                   5  1175.000000  175.000000  2020     1
# N2WP                   4  1150.000000  200.000000  2020     1
# N3CD                   7  1215.000000   65.000000  2020     1
# N3CS                   1  1070.000000    0.000000  2020     1
# N3DT                   1  1090.000000    0.000000  2020     1
# N3NB                   1  1070.000000    0.000000  2020     1
# N3ND                   1  1090.000000    0.000000  2020     1
# N3PC                   1  1150.000000    0.000000  2020     1
# N3TK                   5  1070.000000    0.000000  2020     1
# N3TL                   1  1350.000000    0.000000  2020     1
# N3TN                   7  1150.000000    0.000000  2020     1
# N3WR                   1  1070.000000    0.000000  2020     1
# W1CP                   4  1383.333333  164.991582  2020     1
# W1DT                  16  1390.000000   10.000000  2020     1
# W1IN                  12  1380.000000   16.329932  2020     1
# W1SR                  10  1440.000000   60.000000  2020     1

# %%
SADA['1']['CPM'].mean()

# %%
import datetime as dt
dt.datetime.now().year+1
# Out:
# 2021

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
X, y = make_regression(n_features=4, n_informative=2, random_state=0, shuffle=False)

# %%
pd.DataFrame({'a':[1,2]}).append(pd.Series({'b':3}), ignore_index=True)
# Out:
#      a    b
# 0  1.0  NaN
# 1  2.0  NaN
# 2  NaN  3.0
